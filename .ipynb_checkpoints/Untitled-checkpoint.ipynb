# %%
from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary
from gensim.models import *
import pyLDAvis
import pyLDAvis.gensim

# %%
common_dictionary = Dictionary(common_texts)
common_corpus = [common_dictionary.doc2bow(text) for text in common_texts]

# %%
lda = LdaModel(common_corpus, num_topics=10)

# %%
print(lda.print_topics())
# Out:
# [(0, '0.212*"7" + 0.212*"2" + 0.212*"5" + 0.212*"8" + 0.019*"9" + 0.019*"10" + 0.019*"1" + 0.019*"0" + 0.019*"4" + 0.019*"11"'), (1, '0.262*"6" + 0.262*"3" + 0.262*"7" + 0.024*"9" + 0.024*"10" + 0.024*"5" + 0.024*"1" + 0.024*"11" + 0.024*"2" + 0.024*"0"'), (2, '0.083*"9" + 0.083*"10" + 0.083*"5" + 0.083*"7" + 0.083*"1" + 0.083*"2" + 0.083*"8" + 0.083*"11" + 0.083*"6" + 0.083*"0"'), (3, '0.262*"11" + 0.262*"10" + 0.262*"4" + 0.024*"9" + 0.024*"5" + 0.024*"7" + 0.024*"1" + 0.024*"2" + 0.024*"8" + 0.024*"0"'), (4, '0.083*"9" + 0.083*"10" + 0.083*"5" + 0.083*"11" + 0.083*"1" + 0.083*"7" + 0.083*"8" + 0.083*"3" + 0.083*"0" + 0.083*"4"'), (5, '0.187*"9" + 0.098*"5" + 0.098*"4" + 0.098*"3" + 0.098*"7" + 0.098*"0" + 0.098*"6" + 0.098*"10" + 0.098*"11" + 0.009*"1"'), (6, '0.083*"9" + 0.083*"10" + 0.083*"5" + 0.083*"7" + 0.083*"2" + 0.083*"11" + 0.083*"1" + 0.083*"8" + 0.083*"0" + 0.083*"3"'), (7, '0.083*"9" + 0.083*"10" + 0.083*"7" + 0.083*"11" + 0.083*"5" + 0.083*"8" + 0.083*"3" + 0.083*"2" + 0.083*"4" + 0.083*"1"'), (8, '0.344*"9" + 0.344*"10" + 0.031*"5" + 0.031*"1" + 0.031*"7" + 0.031*"11" + 0.031*"0" + 0.031*"4" + 0.031*"3" + 0.031*"2"'), (9, '0.256*"5" + 0.256*"1" + 0.134*"8" + 0.134*"0" + 0.134*"2" + 0.012*"9" + 0.012*"10" + 0.012*"7" + 0.012*"4" + 0.012*"11"')]

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda, common_corpus, common_dictionary, sort_topics=True, n_jobs=1)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 9     -0.209690  0.105648       1        1  21.077173
# 5      0.092052 -0.037885       2        1  20.018007
# 3      0.166405  0.088283       3        1  13.585112
# 0     -0.164804 -0.029587       4        1  13.318645
# 8      0.131825  0.071475       5        1  12.821960
# 1      0.015163 -0.213091       6        1  10.042805
# 7     -0.007733  0.003790       7        1   2.284075
# 6     -0.007741  0.003788       8        1   2.284075
# 4     -0.007741  0.003789       9        1   2.284075
# 2     -0.007737  0.003789      10        1   2.284075, topic_info=      Term      Freq     Total Category  logprob  loglift
# 9    trees  2.000000  2.000000  Default  12.0000  12.0000
# 10   graph  3.000000  3.000000  Default  11.0000  11.0000
# 1    human  2.000000  2.000000  Default  10.0000  10.0000
# 7     user  2.000000  2.000000  Default   9.0000   9.0000
# 11  minors  2.000000  2.000000  Default   8.0000   8.0000
# ..     ...       ...       ...      ...      ...      ...
# 1    human  0.055194  2.191623  Topic10  -2.4850   0.0977
# 7     user  0.055198  2.655317  Topic10  -2.4849  -0.0942
# 9    trees  0.055228  2.899485  Topic10  -2.4844  -0.1816
# 10   graph  0.055207  3.319045  Topic10  -2.4847  -0.3171
# 5   system  0.055200  3.452755  Topic10  -2.4849  -0.3568
#
# [132 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 0         1  0.509022   computer
# 0         2  0.509022   computer
# 8         1  0.456841        eps
# 8         4  0.456841        eps
# 10        2  0.301291      graph
# 10        3  0.301291      graph
# 10        5  0.301291      graph
# 1         1  0.912566      human
# 2         1  0.456840  interface
# 2         4  0.456840  interface
# 11        2  0.463579     minors
# 11        3  0.463579     minors
# 3         2  0.522864   response
# 3         6  0.522864   response
# 4         2  0.463585     survey
# 4         3  0.463585     survey
# 5         1  0.579248     system
# 5         2  0.289624     system
# 5         4  0.289624     system
# 6         2  0.522863       time
# 6         6  0.522863       time
# 9         2  0.344889      trees
# 9         5  0.344889      trees
# 7         2  0.376603       user
# 7         4  0.376603       user
# 7         6  0.376603       user, R=12, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[10, 6, 4, 1, 9, 2, 8, 7, 5, 3])

# %%
file=open("a.html")
pyLDAvis.save_html(vis, a.html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-683bc09d8b58> in <module>
# ----> 1 pyLDAvis.save_html(vis, a.html)
#
# NameError: name 'a' is not defined
